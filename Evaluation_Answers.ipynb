# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os

# %%
folder = '/content/drive/MyDrive/text_data'

df = pd.DataFrame()
for file in ['S10_question_answer_pairs.txt','S09_question_answer_pairs.txt','S08_question_answer_pairs.txt']:
    filename = os.path.join(folder, file)
    df_tmp = pd.read_csv(filename, encoding='latin1', sep='\t').drop_duplicates(subset="Question")
    print(filename, len(df_tmp))
    df = pd.concat([df,df_tmp])
# Out:
# /content/drive/MyDrive/text_data/S10_question_answer_pairs.txt 832
# /content/drive/MyDrive/text_data/S09_question_answer_pairs.txt 598
# /content/drive/MyDrive/text_data/S08_question_answer_pairs.txt 1033

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2463 entries, 0 to 1714
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ArticleTitle              832 non-null    object
#  1   Question                  2461 non-null   object
#  2   Answer                    2190 non-null   object
#  3   DifficultyFromQuestioner  1570 non-null   object
#  4   DifficultyFromAnswerer    2185 non-null   object
#  5   ArticleFile               2461 non-null   object
#  6   ï»¿ArticleTitle           1631 non-null   object
# dtypes: object(7)
# memory usage: 153.9+ KB

# %%
# normalize the name of columns
df.columns = ['articleTitle','question','answer','difficultyFromQuestioner',
              'difficultyFromAnswerer','articleFile',"articleTitle_to_drop"]

# drop the last column
df.drop('articleTitle_to_drop', axis=1, inplace=True)

# %%
# nb of na values in each column
df.isna().sum()
# Out:
# articleTitle                1631
# question                       2
# answer                       273
# difficultyFromQuestioner     893
# difficultyFromAnswerer       278
# articleFile                    2
# dtype: int64

# %%
# drop na values
print('original df length: ',len(df))
df.dropna(subset=['question'], inplace=True)
df.dropna(subset=['answer'], inplace=True)
df.dropna(subset=['articleTitle'], inplace=True)
df = df[~df.question.str.contains('#')] # remove badly formatted questions
df = df[~df.answer.isin(['no','yes','Yes','No','No,','Yes,','No.','Yes.','yes.','no.'])] # remove yes/no questions
print('new df length: ',len(df))
# Out:
# original df length:  2463
# new df length:  511

# %%
pd.options.display.max_colwidth=None
df.head()
# Out:
#        articleTitle  \
# 0  Alessandro_Volta
# 2  Alessandro_Volta
# 4  Alessandro_Volta
# 6  Alessandro_Volta
# 8  Alessandro_Volta
#
#                                                     question  \
# 0             Was Alessandro Volta a professor of chemistry?
# 2  Did Alessandro Volta invent the remotely operated pistol?
# 4             Was Alessandro Volta taught in public schools?
# 6                            Who did Alessandro Volta marry?
# 8                  What did Alessandro Volta invent in 1800?
#
#                                                       answer  \
# 0         Alessandro Volta was not a professor of chemistry.
# 2  Alessandro Volta did invent the remotely operated pistol.
# 4                        Volta was taught in public schools.
# 6                 Alessandro Volta married Teresa Peregrini.
# 8       In 1800, Alessandro Volta invented the voltaic pile.
#
#   difficultyFromQuestioner difficultyFromAnswerer   articleFile
# 0                     easy                   easy  S10_set4_a10
# 2                     easy                   easy  S10_set4_a10
# 4                     easy                   easy  S10_set4_a10
# 6                   medium                 medium  S10_set4_a10
# 8                   medium                   easy  S10_set4_a10

# %% [markdown]
# ----

# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
# load question-answering model

from transformers import pipeline
qa_model = pipeline("question-answering")
# Out:
# No model was supplied, defaulted to distilbert-base-cased-distilled-squad and revision 626af31 (https://huggingface.co/distilbert-base-cased-distilled-squad).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
def answer_question_given_article(question, article_name):
    '''
    given the question, read the article and use it as a context and return a dictionary with an
    answer and a score and the position of the answer in the article
    '''
    folder_name = '/content/drive/MyDrive/text_data/text_data'
    article_file = str(df[df.articleTitle==article_name].articleFile.unique()[0]) + '.txt.clean'
    article_path = os.path.join(folder_name, article_file)

    with open(article_path, 'r') as file:
        context = file.read().replace('\n', '')

    return qa_model(question, context)

# %%
# %%time

# question example and the time it takes to answer it
question_example = """In 1602, the British East India Company's first voyage, commanded by Sir who, arrived in Aceh and sailed on to Banten where they were allowed to build a trading post?"""
answer_question_given_article(question_example, "Jakarta")
# Out:
# CPU times: user 29.3 s, sys: 104 ms, total: 29.4 s
# Wall time: 41.5 s
# {'score': 0.8335646986961365,
#  'start': 3262,
#  'end': 3281,
#  'answer': 'Sir James Lancaster'}

# %%
df[df.question==question_example]
# Out:
#     articleTitle  \
# 663      Jakarta
#
#                                                                                                                                                                    question  \
# 663  In 1602, the British East India Company's first voyage, commanded by Sir who, arrived in Aceh and sailed on to Banten where they were allowed to build a trading post?
#
#               answer difficultyFromQuestioner difficultyFromAnswerer  \
# 663  James Lancaster                      NaN                 medium
#
#      articleFile
# 663  S10_set3_a5

# %%
df_sample = df.sample(30)

df_sample['answer_from_model'] = df_sample.apply(lambda x: answer_question_given_article(x.question, x.articleTitle), axis=1)

df_sample['models_answer'] = df_sample['answer_from_model'].map(lambda x:x['answer'])

df_sample['models_score'] = df_sample['answer_from_model'].map(lambda x:x['score'])

# %%
cols_of_interst = ['question','answer','models_answer','models_score']
df_sample.head()[cols_of_interst]
# Out:
#                                                      question  \
# 100                                Do worker ants have wings?
# 549              Which guitars use three single-coil pickups?
# 1129     What are the two main groups of Portuguese dialects?
# 1131  What event marked the end of the Old Portuguese period?
# 172                    Is Berlin the capital city of Germany?
#
#                                                                      answer  \
# 100                                      No, worker ants do not have wings.
# 549                                         Fender Statocaster type guitars
# 1129                             Those of Brazil and those of the Old World
# 1131  The publication of the Cancioneiro Geral by Garcia de Resende in 1516
# 172                                  Berlin is the capital city of Germany.
#
#                                                                           models_answer  \
# 100                                                                 do not have workers
# 549                                                                    Gibson Les Pauls
# 1129                                                              Galician and the Fala
# 1131                              Portugal established a colonial and commercial empire
# 172   Berlin as a German state has accumulated more debt than any other city in Germany
#
#       models_score
# 100       0.447633
# 549       0.854811
# 1129      0.917560
# 1131      0.192172
# 172       0.583601

# %%
pip install -Uq sentence-transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.0 MB/s eta 0:00:00
#   Building wheel for sentence-transformers (setup.py) ... done

# %%
def how_similar(sent1, sent2, model):
    '''
    compute sentence similarity.
    '''
    #Compute embedding for both lists
    embedding_1= model.encode(str(sent1), convert_to_tensor=True)
    embedding_2 = model.encode(str(sent2), convert_to_tensor=True)

    return util.pytorch_cos_sim(embedding_1, embedding_2).item()

from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2')
df_sample['answers_similarity'] = df_sample.apply(lambda x: how_similar(x.answer, x.models_answer, model=model), axis=1)
# Out:
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
# let's inspect
df_sample[['question','answer','models_answer','answers_similarity','models_score']].sort_values(by='answers_similarity', ascending=False)
# Out:
#                                                                                         question  \
# 1456                                                              At what age can a zebra breed?
# 615                                                               Where was Isaac Newton buried?
# 1140  (where French has a similar phenomenon, with alveolar affricates instead of postalveolars?
# 309                                        Do linguists often view Chinese as a language family?
# 1173                                             Is San Franscico a popular tourist destination?
# 172                                                       Is Berlin the capital city of Germany?
# 1160                                                  Who laid down the Peter and Paul Fortress?
# 1103                                                  What are a piano's keys generally made of?
# 106                                                               Where are bullet ants located?
# 1208                                              Give an example of the ten Beta World Cities.
# 112                                                                     Do all ants build nests?
# 549                                                 Which guitars use three single-coil pickups?
# 848                                                           How are new words formed in Malay?
# 675                                                Is there a statue of Watt in the White House?
# 100                                                                   Do worker ants have wings?
# 1185                       How does poverty in San Francisco compare to the nation-wide average?
# 1050                                                           Where is the mouth of an octopus?
# 460                                                        Who wrote the first novel in Finnish?
# 200                                 When did Berlin give up its status as a free Hanseatic city?
# 1131                                     What event marked the end of the Old Portuguese period?
# 1354                           Was Vietnamese formally written using the Chinese writing system?
# 266                                          What is Charles-Augustin de Coulomb best known for?
# 1129                                        What are the two main groups of Portuguese dialects?
# 488                                When did concert flutes begin appearing in concert ensembles?
# 817                                                        What is the caridoid escape reaction?
# 1359                                           What are the three dialect regions of Vietnamese?
# 110                                                       What is the most common color of ants?
# 319                                                   What is the total number of Chinese words?
# 960                                          How many international airports does Montreal have?
# 993                          Give an example of the highest growth rates of any city in Africa.
#
#                                                                                                                             answer  \
# 1456                                                                                                                   five or six
# 615                                                                                                              Westminster Abbey
# 1140                                                                                                                       Quebec.
# 309                                                                        Yes, linguists often view Chinese as a language family.
# 1173                                                            Yes. San Francisco is a popular international tourist destination.
# 172                                                                                         Berlin is the capital city of Germany.
# 1160                                                                                                              Peter the Great
# 1103                                                                          Piano keys are generally made of spruce or basswood.
# 106                                                                          Bullet ants are located in Central and South America.
# 1208                                                                                                                 San Trancisco
# 112                                                                                                  No, not all ants build nests.
# 549                                                                                                Fender Statocaster type guitars
# 848                                                                                                                 three methods.
# 675        No, a colossal statue of Watt by Chantrey was placed in Westminster Abbey, and later was moved to St. Paul's Cathedral.
# 100                                                                                             No, worker ants do not have wings.
# 1185  The city's poverty rate is 11.8% and the number of families in poverty stands at 7.4%, both lower than the national average.
# 1050                                                                   The mouth of an octopus is at the center point of the arms.
# 460                                                                                                                   Aleksis Kivi
# 200                                                                    In 1451 Berlin gave up its status as a free Hanseatic city.
# 1131                                                         The publication of the Cancioneiro Geral by Garcia de Resende in 1516
# 1354                                                      Yes, Vietnamese was *formerly* written using the Chinese writing system.
# 266                                                                                 He is best known for developing Coulomb's law.
# 1129                                                                                    Those of Brazil and those of the Old World
# 488                                                                                                               the 16th-century
# 817                                                             Swimming backwards quickly by curling and uncurling their abdomen.
# 1359                                                                              The three regions are North, Central, and South.
# 110                                                                                                    Most ants are red or black.
# 319                                                               The Hanyu Da Zidian includes 54,678 head entries for characters.
# 960                                                                                       Montreal has two international airports.
# 993                   The growth rate of Nairobi is currently 6.9%,  an example of the highest growth rates of any city in Africa.
#
#                                                                           models_answer  \
# 1456                                                                        five or six
# 615                                                                   Westminster Abbey
# 1140                                                                             Quebec
# 309                                   Linguists often view Chinese as a language family
# 1173                       San Francisco is a popular international tourist destination
# 172   Berlin as a German state has accumulated more debt than any other city in Germany
# 1160                                                             Tsar Peter I of Russia
# 1103                                                                 spruce or basswood
# 106                                                           Central and South America
# 1208                                                                      San Francisco
# 112                                          it can make nests between sheets of paper.
# 549                                                                    Gibson Les Pauls
# 848                                                   by joining two or more root words
# 675                               A statue of him, Boulton and Murdoch is in Birmingham
# 100                                                                 do not have workers
# 1185                                                                              11.8%
# 1050                                                               Haliphron atlanticus
# 460                                                                            Abckiria
# 200                                                                                1451
# 1131                              Portugal established a colonial and commercial empire
# 1354                                                                         diphthongs
# 266                                           his contribution to retaining wall design
# 1129                                                              Galician and the Fala
# 488                                                                                1982
# 817                                                   A speed of five meters per second
# 1359                                                        Ha Noi and Ho Chi Minh City
# 110                                                                          univoltine
# 319                                                                             117,660
# 960                                                                                 two
# 993                                                                       othersNairobi
#
#       answers_similarity  models_score
# 1456            1.000000      0.058898
# 615             1.000000      0.934218
# 1140            0.970008      0.729869
# 309             0.943564      0.337965
# 1173            0.881920      0.490606
# 172             0.687285      0.583601
# 1160            0.620028      0.691974
# 1103            0.542312      0.872846
# 106             0.536672      0.252010
# 1208            0.533199      0.768252
# 112             0.457674      0.279288
# 549             0.445778      0.854811
# 848             0.398937      0.668379
# 675             0.377266      0.078695
# 100             0.374343      0.447633
# 1185            0.373304      0.923678
# 1050            0.358001      0.784247
# 460             0.333655      0.885996
# 200             0.296909      0.930939
# 1131            0.295758      0.192172
# 1354            0.254100      0.249133
# 266             0.246197      0.512408
# 1129            0.236060      0.917560
# 488             0.224068      0.215902
# 817             0.221661      0.341974
# 1359            0.194685      0.991693
# 110             0.168585      0.841803
# 319             0.117177      0.337873
# 960             0.115839      0.827406
# 993             0.014972      0.900710

# %% [markdown]
# Not bad for a model that never saw any example nor has it been finetuned on specific corpora
